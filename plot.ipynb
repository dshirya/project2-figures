# %%
from plot import plot_scatter, plot_filtered_scatter, plot_zoom_scatter
import pandas as pd

df = pd.read_excel("plot_data.xlsx")
#plot_scatter(df)

# %%
plot_filtered_scatter(df)

# %%
plot_zoom_scatter(df)

# %%
from plot import plot_zoom_color_scatter

plot_zoom_color_scatter(df)
